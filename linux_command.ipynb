# %% [markdown]
# <a href="https://colab.research.google.com/github/azureiraraavis-png/linux/blob/main/linux_command.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
man man

# %%
# !ls
# Out:
# sample_data

# %%
# !uname -a
# Out:
# Linux 65c72ed7d0a1 6.6.113+ #1 SMP Mon Feb  2 12:27:57 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux
